# %%
import numpy as np
import scipy.io as spio
import scipy.stats as spst

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import plot_utils as pu
import color_scheme as cs

# %%
hall1dat = spio.loadmat('./dataBehavior/VR19_VR20211022170517_hall1_trialdata.mat')
hall2dat = spio.loadmat('./dataBehavior/VR19_VR20211022170517_hall2_trialdata.mat')
hall3dat = spio.loadmat('./dataBehavior/VR19_VR20211022170517_hall3_trialdata.mat')
hall4dat = spio.loadmat('./dataBehavior/VR19_VR20211022170517_hall4_trialdata.mat')

speedhall1 = hall1dat['binned_speed']
speedhall2 = hall2dat['binned_speed']
speedhall3 = hall3dat['binned_speed']
speedhall4 = hall4dat['binned_speed']

# %%
colors=['orange', 'indianred', 'c', 'royalblue']
labels = ['Snowy Chair Star', 'Snowy Star Chair', 'Desert Drum Star', 'Desert Star Drum']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,3))
xpos = np.linspace(0,100,speedhall1.shape[1])*4
for s, spd in enumerate([speedhall1, speedhall2, speedhall3, speedhall4]):
    y = np.nanmean(spd*4,0)
    yerr = spst.iqr(spd,0,rng=[25,75],nan_policy='omit')
    ax.plot(xpos, y, label=labels[s], color=colors[s], linewidth=3)
    ax.fill_between(xpos, y - yerr, y + yerr, color=colors[s], alpha=0.5)
ax.plot([200]*65,np.linspace(0,65,65),'k--', linewidth=2)
ax.plot([400]*65,np.linspace(0,65,65),'k--', linewidth=2) 
ax.set_xlabel('Linear Position (cm)', fontsize=18, labelpad=2, fontweight='bold')
ax.set_ylabel('Speed (cm/s)', fontsize=18, labelpad=2, fontweight='bold')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
ax.set_xticks([0,100,200,300,400])
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
#ax.set_ylim([0,25])
#fig.legend(frameon=False, fontsize=16, loc=0)
plt.tight_layout()
plt.savefig('Fig1Behavior.png', dpi=300)

# %%
colors=['orange', 'indianred', 'c', 'royalblue']
labels = ['Snowy Chair Star', 'Snowy Star Chair', 'Desert Drum Star', 'Desert Star Drum']
indices = np.arange(0, speedhall1.shape[0],10)
alphas = np.linspace(0.2,1,len(indices)-1)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4,3))
xpos = np.linspace(0,100,speedhall1.shape[1])*4
for idx in range(len(indices)-1):
    sp = speedhall1[indices[idx]:indices[idx+1]]*4
    ax.plot(xpos, np.nanmean(sp,0), color=colors[0], linewidth=1.25, alpha=alphas[idx])
#ax.plot([50]*30,np.linspace(0,30,30),'k--', linewidth=2)
ax.plot([400]*65,np.linspace(0,65,65),'k--', linewidth=2) 
ax.set_xlabel('Linear Position (cm)', fontsize=18, labelpad=2, fontweight='bold')
ax.set_ylabel('Speed (cm/s)', fontsize=18, labelpad=2, fontweight='bold')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
ax.set_xticks([0,50,100,150,200,250,300,350,400])
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
#ax.set_ylim([0,20])
ax.set_xlim([250,400])
plt.tight_layout()
plt.savefig('Fig2a.png', dpi=300)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4,3))
for idx in range(len(indices)-1):
    sp = speedhall2[indices[idx]:indices[idx+1]]*4
    ax.plot(xpos, np.nanmean(sp,0), color=colors[1], linewidth=1.25, alpha=alphas[idx])
ax.plot([200]*65,np.linspace(0,65,65),'k--', linewidth=2)
#ax.plot([100]*30,np.linspace(0,30,30),'k--', linewidth=2) 
ax.set_xlabel('Linear Position (cm)', fontsize=18, labelpad=2, fontweight='bold')
ax.set_ylabel('Speed (cm/s)', fontsize=18, labelpad=2, fontweight='bold')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
ax.set_xticks([0,50,100,150,200,250,300,350,400])
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
#ax.set_ylim([0,20])
ax.set_xlim([50,200])
plt.tight_layout()
plt.savefig('Fig2b.png', dpi=300)    


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4,3))
for idx in range(len(indices)-1):
    sp = speedhall3[indices[idx]:indices[idx+1]]*4
    ax.plot(xpos, np.nanmean(sp,0), color=colors[2], linewidth=1.25, alpha=alphas[idx])
#ax.plot([50]*30,np.linspace(0,30,30),'k--', linewidth=2)
ax.plot([200]*65,np.linspace(0,65,65),'k--', linewidth=2) 
ax.set_xlabel('Linear Position (cm)', fontsize=18, labelpad=2, fontweight='bold')
ax.set_ylabel('Speed (cm/s)', fontsize=18, labelpad=2, fontweight='bold')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
ax.set_xticks([0,25,50,75,100])
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
#ax.set_ylim([0,20])
ax.set_xlim([50,200])
plt.tight_layout()
plt.savefig('Fig2c.png', dpi=300)    

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4,3))
for idx in range(len(indices)-1):
    sp = speedhall4[indices[idx]:indices[idx+1]]*4
    ax.plot(xpos, np.nanmean(sp,0), color=colors[3], linewidth=1.25, alpha=alphas[idx])
ax.plot([200]*60,np.linspace(0,60,60),'k--', linewidth=2)
#ax.plot([100]*30,np.linspace(0,30,30),'k--', linewidth=2) 
ax.set_xlabel('Linear Position (cm)', fontsize=18, labelpad=2, fontweight='bold')
ax.set_ylabel('Speed (cm/s)', fontsize=18, labelpad=2, fontweight='bold')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
ax.set_xticks([0,50,100,150,200])
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
#ax.set_ylim([0,20])
ax.set_xlim([50,200])
plt.tight_layout()
plt.savefig('Fig2d.png', dpi=300)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: RuntimeWarning: Mean of empty slice
